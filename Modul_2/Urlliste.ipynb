# %%
import pandas as pd

# %%
import requests
url = "https://www.bibsonomy.org/json/search/sozialwissenschaft?items=1000"
url2 = "https://www.bibsonomy.org/json/search/Datenanaylse?items=1000"
urlliste = [url, url2]

# %%
dfs = []

# %%
def create_df_from_urls(urlliste):
    for url in urlliste:
        result=requests.get(url)
        data=result.json()
        df_bibsonomy = pd.DataFrame(data["items"])
        dfs.append(df_bibsonomy)

# %%
create_df_from_urls(urlliste)
dfs_gesamt=pd.concat(dfs)

# %%
dfs_gesamt
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/c379d69c7bc17107...
# 1       Bookmark  https://www.bibsonomy.org/url/77f94106350b0fee...
# 2       Bookmark  https://www.bibsonomy.org/url/c655583d71872516...
# 3       Bookmark  https://www.bibsonomy.org/url/1da111d50267cbf0...
# 4       Bookmark  https://www.bibsonomy.org/url/1da111d50267cbf0...
# ..           ...                                                ...
# 662  Publication  https://www.bibsonomy.org/bibtex/2c16532c1d170...
# 663  Publication  https://www.bibsonomy.org/bibtex/20cb00b886a82...
# 664  Publication  https://www.bibsonomy.org/bibtex/23d5a800b4d0f...
# 665  Publication  https://www.bibsonomy.org/bibtex/272791fceda96...
# 666  Publication  https://www.bibsonomy.org/bibtex/27b3d71007fec...
#
#                                                   tags  \
# 0                      [sozialwissenschaft, thesaurus]
# 1    [zis, items, sozialwissenschaft, gesis, method...
# 2    [geisteswissenschaften, sozialwissenschaften, ...
# 3    [fachzugang, Sozialpolitik, Demographie, bibli...
# 4    [fachzugang, Sozialpolitik, Demographie, bibli...
# ..                                                 ...
# 662                         [dnb, Gesundheit, Medizin]
# 663                         [Naturwissenschaften, dnb]
# 664  [Kartographie, Biowissenschaften, Naturwissens...
# 665     [handwerk, selbständigkeit, solo-selbständige]
# 666        [qualitative_sozialforschung, Qualität, UB]
#
#                             intraHash  \
# 0    c379d69c7bc171071144a733f990ae7a
# 1    77f94106350b0feecbeb518816b1c559
# 2    c655583d718725160a23134ce8cf2d23
# 3    1da111d50267cbf0c119e756f6b6a7e2
# 4    1da111d50267cbf0c119e756f6b6a7e2
# ..                                ...
# 662  c16532c1d1706cf0cc3f32a09a8fcd6a
# 663  0cb00b886a82c0453ddd339c34e9396a
# 664  3d5a800b4d0f904f4927ddb99d553d98
# 665  72791fceda96f36ec4146d1bd9771048
# 666  7b3d71007fec671e998507a85c8b788f
#
#                                                  label        user  \
# 0                       thesaurus sozialwissenschaften       serin
# 1                              Inhaltsübersicht: GESIS  tobidiplom
# 2         Startseite | Geistes- & Sozialwissenschaften       wdees
# 3                    vascoda Fachzugang für Soziologie     vascoda
# 4                    vascoda Fachzugang für Soziologie   mhohlfeld
# ..                                                 ...         ...
# 662  New statistical methods of genome-scale data a...  genealogie
# 663  Probleme der Datenanalyse bei hochenergetische...  genealogie
# 664  Probleme der Datenanalyse bei hochenergetische...  genealogie
# 665  Soloselbstständigkeit im Handwerk : Anzahl, Be...   meneteqel
# 666  Empirische Befunde zur Qualität qualitativer S...       wdees
#
#                                            description                 date  \
# 0                                                       2009-01-23 17:53:16
# 1      GESIS Leibniz Institut für Sozialwissenschaften  2010-07-07 07:45:23
# 2                                                       2019-12-13 08:48:54
# 3    enthält u.a. auch Politikwissenschaft, Sozialp...  2009-02-23 14:01:45
# 4    enthält u.a. auch Politikwissenschaft, Sozialp...  2009-02-23 14:01:45
# ..                                                 ...                  ...
# 662                                                     2015-09-10 03:12:45
# 663                                                     2016-05-31 06:01:03
# 664                                                     2015-09-09 03:35:29
# 665                                                     2016-05-09 17:59:48
# 666                                                     2007-10-12 09:45:53
#
#               changeDate  count  ... added-at biburl shortauthor addresss  \
# 0    2009-01-23 17:53:16      1  ...      NaN    NaN         NaN      NaN
# 1    2010-07-07 07:45:23      1  ...      NaN    NaN         NaN      NaN
# 2    2019-12-13 08:48:54      1  ...      NaN    NaN         NaN      NaN
# 3    2009-08-28 16:33:14      2  ...      NaN    NaN         NaN      NaN
# 4    2009-03-10 15:05:43      2  ...      NaN    NaN         NaN      NaN
# ..                   ...    ...  ...      ...    ...         ...      ...
# 662  2015-09-10 03:20:54      1  ...      NaN    NaN         NaN      NaN
# 663  2016-05-31 06:01:03      1  ...      NaN    NaN         NaN      NaN
# 664  2015-09-09 03:35:29      1  ...      NaN    NaN         NaN      NaN
# 665  2016-05-09 17:59:48      1  ...      NaN    NaN         NaN      NaN
# 666  2007-10-12 09:45:53      1  ...      NaN    NaN         NaN      NaN
#
#     bibsource x.sortdate __markedentry x.asin referencetype issue
# 0         NaN        NaN           NaN    NaN           NaN   NaN
# 1         NaN        NaN           NaN    NaN           NaN   NaN
# 2         NaN        NaN           NaN    NaN           NaN   NaN
# 3         NaN        NaN           NaN    NaN           NaN   NaN
# 4         NaN        NaN           NaN    NaN           NaN   NaN
# ..        ...        ...           ...    ...           ...   ...
# 662       NaN        NaN           NaN    NaN           NaN   NaN
# 663       NaN        NaN           NaN    NaN           NaN   NaN
# 664       NaN        NaN           NaN    NaN           NaN   NaN
# 665       NaN        NaN           NaN    NaN           NaN   NaN
# 666       NaN        NaN           NaN    NaN           NaN   NaN
#
# [1850 rows x 105 columns]

# %%
data.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
type(data["items"])
# Out:
# list

# %%
df_bibsonomy = pd.DataFrame(data["items"])
df_bibsonomy2 = pd.DataFrame(data2["items"])
df_bibsonomy_gesamt = pd.concat([df_bibsonomy, df_bibsonomy2])

# %%
df_bibsonomy_gesamt
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/c379d69c7bc17107...
# 1       Bookmark  https://www.bibsonomy.org/url/77f94106350b0fee...
# 2       Bookmark  https://www.bibsonomy.org/url/c655583d71872516...
# 3       Bookmark  https://www.bibsonomy.org/url/1da111d50267cbf0...
# 4       Bookmark  https://www.bibsonomy.org/url/1da111d50267cbf0...
# ..           ...                                                ...
# 662  Publication  https://www.bibsonomy.org/bibtex/2c16532c1d170...
# 663  Publication  https://www.bibsonomy.org/bibtex/20cb00b886a82...
# 664  Publication  https://www.bibsonomy.org/bibtex/23d5a800b4d0f...
# 665  Publication  https://www.bibsonomy.org/bibtex/272791fceda96...
# 666  Publication  https://www.bibsonomy.org/bibtex/27b3d71007fec...
#
#                                                   tags  \
# 0                      [sozialwissenschaft, thesaurus]
# 1    [zis, items, sozialwissenschaft, gesis, method...
# 2    [geisteswissenschaften, sozialwissenschaften, ...
# 3    [fachzugang, Sozialpolitik, Demographie, bibli...
# 4    [fachzugang, Sozialpolitik, Demographie, bibli...
# ..                                                 ...
# 662                         [dnb, Gesundheit, Medizin]
# 663                         [Naturwissenschaften, dnb]
# 664  [Kartographie, Biowissenschaften, Naturwissens...
# 665     [handwerk, selbständigkeit, solo-selbständige]
# 666        [qualitative_sozialforschung, Qualität, UB]
#
#                             intraHash  \
# 0    c379d69c7bc171071144a733f990ae7a
# 1    77f94106350b0feecbeb518816b1c559
# 2    c655583d718725160a23134ce8cf2d23
# 3    1da111d50267cbf0c119e756f6b6a7e2
# 4    1da111d50267cbf0c119e756f6b6a7e2
# ..                                ...
# 662  c16532c1d1706cf0cc3f32a09a8fcd6a
# 663  0cb00b886a82c0453ddd339c34e9396a
# 664  3d5a800b4d0f904f4927ddb99d553d98
# 665  72791fceda96f36ec4146d1bd9771048
# 666  7b3d71007fec671e998507a85c8b788f
#
#                                                  label        user  \
# 0                       thesaurus sozialwissenschaften       serin
# 1                              Inhaltsübersicht: GESIS  tobidiplom
# 2         Startseite | Geistes- & Sozialwissenschaften       wdees
# 3                    vascoda Fachzugang für Soziologie     vascoda
# 4                    vascoda Fachzugang für Soziologie   mhohlfeld
# ..                                                 ...         ...
# 662  New statistical methods of genome-scale data a...  genealogie
# 663  Probleme der Datenanalyse bei hochenergetische...  genealogie
# 664  Probleme der Datenanalyse bei hochenergetische...  genealogie
# 665  Soloselbstständigkeit im Handwerk : Anzahl, Be...   meneteqel
# 666  Empirische Befunde zur Qualität qualitativer S...       wdees
#
#                                            description                 date  \
# 0                                                       2009-01-23 17:53:16
# 1      GESIS Leibniz Institut für Sozialwissenschaften  2010-07-07 07:45:23
# 2                                                       2019-12-13 08:48:54
# 3    enthält u.a. auch Politikwissenschaft, Sozialp...  2009-02-23 14:01:45
# 4    enthält u.a. auch Politikwissenschaft, Sozialp...  2009-02-23 14:01:45
# ..                                                 ...                  ...
# 662                                                     2015-09-10 03:12:45
# 663                                                     2016-05-31 06:01:03
# 664                                                     2015-09-09 03:35:29
# 665                                                     2016-05-09 17:59:48
# 666                                                     2007-10-12 09:45:53
#
#               changeDate  count  ... added-at biburl shortauthor addresss  \
# 0    2009-01-23 17:53:16      1  ...      NaN    NaN         NaN      NaN
# 1    2010-07-07 07:45:23      1  ...      NaN    NaN         NaN      NaN
# 2    2019-12-13 08:48:54      1  ...      NaN    NaN         NaN      NaN
# 3    2009-08-28 16:33:14      2  ...      NaN    NaN         NaN      NaN
# 4    2009-03-10 15:05:43      2  ...      NaN    NaN         NaN      NaN
# ..                   ...    ...  ...      ...    ...         ...      ...
# 662  2015-09-10 03:20:54      1  ...      NaN    NaN         NaN      NaN
# 663  2016-05-31 06:01:03      1  ...      NaN    NaN         NaN      NaN
# 664  2015-09-09 03:35:29      1  ...      NaN    NaN         NaN      NaN
# 665  2016-05-09 17:59:48      1  ...      NaN    NaN         NaN      NaN
# 666  2007-10-12 09:45:53      1  ...      NaN    NaN         NaN      NaN
#
#     bibsource x.sortdate __markedentry x.asin referencetype issue
# 0         NaN        NaN           NaN    NaN           NaN   NaN
# 1         NaN        NaN           NaN    NaN           NaN   NaN
# 2         NaN        NaN           NaN    NaN           NaN   NaN
# 3         NaN        NaN           NaN    NaN           NaN   NaN
# 4         NaN        NaN           NaN    NaN           NaN   NaN
# ..        ...        ...           ...    ...           ...   ...
# 662       NaN        NaN           NaN    NaN           NaN   NaN
# 663       NaN        NaN           NaN    NaN           NaN   NaN
# 664       NaN        NaN           NaN    NaN           NaN   NaN
# 665       NaN        NaN           NaN    NaN           NaN   NaN
# 666       NaN        NaN           NaN    NaN           NaN   NaN
#
# [1850 rows x 105 columns]
